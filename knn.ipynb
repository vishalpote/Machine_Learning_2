# %%
import pandas as pd
from sklearn.datasets import load_iris
iris=load_iris()
data=pd.DataFrame(iris.data,columns=iris.feature_names)

# %%
data
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
data['target']=iris.target

# %%
data.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2  \
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
data['flower_name']=data.target.apply(lambda x: data.target.name[x])

# %%
data.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2  \
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target flower_name
# 0       0           t
# 1       0           t
# 2       0           t
# 3       0           t
# 4       0           t

# %%
from matplotlib import pyplot as plt

# %%
data0=data[data.target==0]
data0.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2  \
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target flower_name
# 0       0           t
# 1       0           t
# 2       0           t
# 3       0           t
# 4       0           t

# %%
data1=data[data.target==1]
data1
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 50                7.0               3.2                4.7               1.4  \
# 51                6.4               3.2                4.5               1.5
# 52                6.9               3.1                4.9               1.5
# 53                5.5               2.3                4.0               1.3
# 54                6.5               2.8                4.6               1.5
# 55                5.7               2.8                4.5               1.3
# 56                6.3               3.3                4.7               1.6
# 57                4.9               2.4                3.3               1.0
# 58                6.6               2.9                4.6               1.3
# 59                5.2               2.7                3.9               1.4
# 60                5.0               2.0                3.5               1.0
# 61                5.9               3.0                4.2               1.5
# 62                6.0               2.2                4.0               1.0
# 63                6.1               2.9                4.7               1.4
# 64                5.6               2.9                3.6               1.3
# 65                6.7               3.1                4.4               1.4
# 66                5.6               3.0                4.5               1.5
# 67                5.8               2.7                4.1               1.0
# 68                6.2               2.2                4.5               1.5
# 69                5.6               2.5                3.9               1.1
# 70                5.9               3.2                4.8               1.8
# 71                6.1               2.8                4.0               1.3
# 72                6.3               2.5                4.9               1.5
# 73                6.1               2.8                4.7               1.2
# 74                6.4               2.9                4.3               1.3
# 75                6.6               3.0                4.4               1.4
# 76                6.8               2.8                4.8               1.4
# 77                6.7               3.0                5.0               1.7
# 78                6.0               2.9                4.5               1.5
# 79                5.7               2.6                3.5               1.0
# 80                5.5               2.4                3.8               1.1
# 81                5.5               2.4                3.7               1.0
# 82                5.8               2.7                3.9               1.2
# 83                6.0               2.7                5.1               1.6
# 84                5.4               3.0                4.5               1.5
# 85                6.0               3.4                4.5               1.6
# 86                6.7               3.1                4.7               1.5
# 87                6.3               2.3                4.4               1.3
# 88                5.6               3.0                4.1               1.3
# 89                5.5               2.5                4.0               1.3
# 90                5.5               2.6                4.4               1.2
# 91                6.1               3.0                4.6               1.4
# 92                5.8               2.6                4.0               1.2
# 93                5.0               2.3                3.3               1.0
# 94                5.6               2.7                4.2               1.3
# 95                5.7               3.0                4.2               1.2
# 96                5.7               2.9                4.2               1.3
# 97                6.2               2.9                4.3               1.3
# 98                5.1               2.5                3.0               1.1
# 99                5.7               2.8                4.1               1.3
#
#     target flower_name
# 50       1           a
# 51       1           a
# 52       1           a
# 53       1           a
# 54       1           a
# 55       1           a
# 56       1           a
# 57       1           a
# 58       1           a
# 59       1           a
# 60       1           a
# 61       1           a
# 62       1           a
# 63       1           a
# 64       1           a
# 65       1           a
# 66       1           a
# 67       1           a
# 68       1           a
# 69       1           a
# 70       1           a
# 71       1           a
# 72       1           a
# 73       1           a
# 74       1           a
# 75       1           a
# 76       1           a
# 77       1           a
# 78       1           a
# 79       1           a
# 80       1           a
# 81       1           a
# 82       1           a
# 83       1           a
# 84       1           a
# 85       1           a
# 86       1           a
# 87       1           a
# 88       1           a
# 89       1           a
# 90       1           a
# 91       1           a
# 92       1           a
# 93       1           a
# 94       1           a
# 95       1           a
# 96       1           a
# 97       1           a
# 98       1           a
# 99       1           a

# %%
data2=data[data.target==2]
data2
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 100                6.3               3.3                6.0               2.5  \
# 101                5.8               2.7                5.1               1.9
# 102                7.1               3.0                5.9               2.1
# 103                6.3               2.9                5.6               1.8
# 104                6.5               3.0                5.8               2.2
# 105                7.6               3.0                6.6               2.1
# 106                4.9               2.5                4.5               1.7
# 107                7.3               2.9                6.3               1.8
# 108                6.7               2.5                5.8               1.8
# 109                7.2               3.6                6.1               2.5
# 110                6.5               3.2                5.1               2.0
# 111                6.4               2.7                5.3               1.9
# 112                6.8               3.0                5.5               2.1
# 113                5.7               2.5                5.0               2.0
# 114                5.8               2.8                5.1               2.4
# 115                6.4               3.2                5.3               2.3
# 116                6.5               3.0                5.5               1.8
# 117                7.7               3.8                6.7               2.2
# 118                7.7               2.6                6.9               2.3
# 119                6.0               2.2                5.0               1.5
# 120                6.9               3.2                5.7               2.3
# 121                5.6               2.8                4.9               2.0
# 122                7.7               2.8                6.7               2.0
# 123                6.3               2.7                4.9               1.8
# 124                6.7               3.3                5.7               2.1
# 125                7.2               3.2                6.0               1.8
# 126                6.2               2.8                4.8               1.8
# 127                6.1               3.0                4.9               1.8
# 128                6.4               2.8                5.6               2.1
# 129                7.2               3.0                5.8               1.6
# 130                7.4               2.8                6.1               1.9
# 131                7.9               3.8                6.4               2.0
# 132                6.4               2.8                5.6               2.2
# 133                6.3               2.8                5.1               1.5
# 134                6.1               2.6                5.6               1.4
# 135                7.7               3.0                6.1               2.3
# 136                6.3               3.4                5.6               2.4
# 137                6.4               3.1                5.5               1.8
# 138                6.0               3.0                4.8               1.8
# 139                6.9               3.1                5.4               2.1
# 140                6.7               3.1                5.6               2.4
# 141                6.9               3.1                5.1               2.3
# 142                5.8               2.7                5.1               1.9
# 143                6.8               3.2                5.9               2.3
# 144                6.7               3.3                5.7               2.5
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target flower_name
# 100       2           r
# 101       2           r
# 102       2           r
# 103       2           r
# 104       2           r
# 105       2           r
# 106       2           r
# 107       2           r
# 108       2           r
# 109       2           r
# 110       2           r
# 111       2           r
# 112       2           r
# 113       2           r
# 114       2           r
# 115       2           r
# 116       2           r
# 117       2           r
# 118       2           r
# 119       2           r
# 120       2           r
# 121       2           r
# 122       2           r
# 123       2           r
# 124       2           r
# 125       2           r
# 126       2           r
# 127       2           r
# 128       2           r
# 129       2           r
# 130       2           r
# 131       2           r
# 132       2           r
# 133       2           r
# 134       2           r
# 135       2           r
# 136       2           r
# 137       2           r
# 138       2           r
# 139       2           r
# 140       2           r
# 141       2           r
# 142       2           r
# 143       2           r
# 144       2           r
# 145       2           r
# 146       2           r
# 147       2           r
# 148       2           r
# 149       2           r

# %%
plt.scatter(data0['sepal length (cm)'],data0['sepal width (cm)'],color="red",marker='+')
plt.scatter(data1['sepal length (cm)'],data1['sepal width (cm)'],color='blue',marker='.')

# %%
plt.scatter(data0['petal length (cm)'],data0['petal width (cm)'],color="red",marker='+')
plt.scatter(data1['petal length (cm)'],data1['petal width (cm)'],color='blue',marker='.')

# %%
x=data.drop(['target','flower_name'],axis='columns')
x.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
y=data.target
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: target, dtype: int32

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
x_train
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 54                 6.5               2.8                4.6               1.5
# 77                 6.7               3.0                5.0               1.7
# 124                6.7               3.3                5.7               2.1
# 10                 5.4               3.7                1.5               0.2
# 106                4.9               2.5                4.5               1.7
# ..                 ...               ...                ...               ...
# 108                6.7               2.5                5.8               1.8
# 126                6.2               2.8                4.8               1.8
# 117                7.7               3.8                6.7               2.2
# 32                 5.2               4.1                1.5               0.1
# 113                5.7               2.5                5.0               2.0
#
# [120 rows x 4 columns]

# %%
x_test
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 21                 5.1               3.7                1.5               0.4
# 88                 5.6               3.0                4.1               1.3
# 79                 5.7               2.6                3.5               1.0
# 99                 5.7               2.8                4.1               1.3
# 47                 4.6               3.2                1.4               0.2
# 112                6.8               3.0                5.5               2.1
# 136                6.3               3.4                5.6               2.4
# 58                 6.6               2.9                4.6               1.3
# 83                 6.0               2.7                5.1               1.6
# 98                 5.1               2.5                3.0               1.1
# 96                 5.7               2.9                4.2               1.3
# 48                 5.3               3.7                1.5               0.2
# 1                  4.9               3.0                1.4               0.2
# 131                7.9               3.8                6.4               2.0
# 132                6.4               2.8                5.6               2.2
# 141                6.9               3.1                5.1               2.3
# 102                7.1               3.0                5.9               2.1
# 37                 4.9               3.6                1.4               0.1
# 81                 5.5               2.4                3.7               1.0
# 42                 4.4               3.2                1.3               0.2
# 84                 5.4               3.0                4.5               1.5
# 16                 5.4               3.9                1.3               0.4
# 114                5.8               2.8                5.1               2.4
# 129                7.2               3.0                5.8               1.6
# 57                 4.9               2.4                3.3               1.0
# 73                 6.1               2.8                4.7               1.2
# 119                6.0               2.2                5.0               1.5
# 93                 5.0               2.3                3.3               1.0
# 20                 5.4               3.4                1.7               0.2
# 22                 4.6               3.6                1.0               0.2

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=3)
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
knn.score(x_test,y_test)
# Out:
# 0.9333333333333333

# %%
from sklearn.metrics import confusion_matrix
# cm=confusion_matrix()
y_pred=knn.predict(x_test)
cm=confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[ 9,  0,  0],
#        [ 0, 11,  1],
#        [ 0,  1,  8]], dtype=int64)

# %%
import seaborn as sn
plt.figure(figsize=(5,2))
sn.heatmap(cm,annot='True')
plt.xlabel('y_pred')
plt.ylabel('Truth')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[62], line 3
#       1 import seaborn as sn
#       2 plt.figure(figsize=(5,2))
# ----> 3 sn.heatmap(cm,annot='True')
#       4 plt.xlabel('y_pred')
#       5 plt.ylabel('Truth')
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\matrix.py:446, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     365 """Plot rectangular data as a color-encoded matrix.
#     366
#     367 This is an Axes-level function and will draw the heatmap into the
#    (...)
#     443
#     444 """
#     445 # Initialize the plotter object
# --> 446 plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     447                       annot_kws, cbar, cbar_kws, xticklabels,
#     448                       yticklabels, mask)
#     450 # Add the pcolormesh kwargs here
#     451 kwargs["linewidths"] = linewidths
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\matrix.py:177, in _HeatMapper.__init__(self, data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, cbar, cbar_kws, xticklabels, yticklabels, mask)
#     175         if annot_data.shape != plot_data.shape:
#     176             err = "`data` and `annot` must have same shape."
# --> 177             raise ValueError(err)
#     178     annot = True
#     180 # Save other attributes to the object
#
# ValueError: `data` and `annot` must have same shape.
